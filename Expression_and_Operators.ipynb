# %%
n=9
print(n,'binary',format(n,'b'))
print(n,'*2=',n<<1,format(n<<1,'b'))
print(n,'/2',n>>1,format(n>>1,'b'))
# Out:
# 9 binary 1001
# 9 *2= 18 10010
# 9 /2 4 100

# %%
x=True
y=False
print('x and y is',x and y)
print('x or y is',x or y)
print('not x is',not x)
print('x and y is',x&y)
# Out:
# x and y is False
# x or y is True
# not x is False
# x and y is False

# %%
x =12
y = 4
print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 4
# 12
# 8

# %%
x = 'Hello World'
print('H' in x)
print('h' not in x)
# Out:
# True
# True

# %%
import cmath
a=complex(20+5j)
b=complex(5+3j)
print('a+b',a+b)
print('a-b',a-b)
print('a*b',a*b)
print('a/b',a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
import math

a = float(input("side 1: "))
b = float(input("side 2: "))
c = float(input("side 3: "))

s = (a + b + c) / 2
area = math.sqrt(abs(s * (s - a) * (s - b) * (s - c)))

print("Area of triangle:", area)
# Out:
# side 1: 5
# side 2: 2
# side 3: 8
# Area of triangle: 7.180703308172536

# %%
ch = input("Enter a letter ")
ch =  ch.lower()
if(ch == 'a' or ch == 'e' or ch == 'i' or ch =='o' or ch == 'u'):
    print("character entered is vowel")
else:
     print("Character is constant")
# Out:
# Enter a letter i
# character entered is vowel

# %%
ch=input("enter a character: ")
if(ch.islower()):
    print("character is lower case")
else:
    print("character is upper case")
# Out:
# enter a character: k
# character is lower case

# %%
n = int(input("enter any number  :"))
for i in range(1,11):
   print(n,"x",i,"=",n *i)
# Out:
# enter any number  :5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# factorial  series  sum
# !

# %%
n = int(input("Enter number: "))

fact = 1
sum = 0

for i in range(1, n + 1):
    fact *= i
    sum += fact

print(sum)

# %% [markdown]
# wap in python to enter the number till the use wants and at the end it will display the maxium number out of thous numbers

# %%
max_num = 0

while True:
    num = int(input("Enter number: "))

    if num > max_num:
        max_num = num

    ch = input("More? (y/n): ")
    if ch == 'n':
        break

print("Max =", max_num)

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        print(f"Car: {self.brand} {self.model} {self.year}")


car1 = Car("Toyota", "Corolla", 2022)
car2 = Car("Tesla", "Model S", 2023)

car1.display_info()
car2.display_info()
# Out:
# Car: Toyota Corolla 2022
# Car: Tesla Model S 2023

# %%
class Student:
  def __init__(self, name, age, rollno):
    self.name = name
    self.age = age
    self.rollno = rollno

  def display(self):
    print(f"Name: {self.name}, Age: {self.age}, Roll No: {self.rollno}")
s1 = Student("Krati", 20, 101)
s2 = Student("Ishika", 21, 102)
s1.display()
s2.display()
# Out:
# Name: Krati, Age: 20, Roll No: 101
# Name: Ishika, Age: 21, Roll No: 102

# %%
class Employee:
    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary


# Dictionary of employees
e = {
    101: Employee(101, "John", 50000),
    102: Employee(102, "Emma", 60000),
    103: Employee(103, "David", 55000)
}


# Display employee details
for emp_id, emp in e.items():
    print(f"ID: {emp.emp_id}, Name: {emp.name}, Salary: {emp.salary}")
# Out:
# ID: 101, Name: John, Salary: 50000
# ID: 102, Name: Emma, Salary: 60000
# ID: 103, Name: David, Salary: 55000
